# %%
import os
import shutil
import glob

def clean_small_tf_event_folders(root_path='.', size_threshold_kb=3):
    """
    Search for TensorFlow event files and delete their parent folders if the file size is below threshold.
    
    Args:
        root_path (str): Root directory to start the search from
        size_threshold_kb (float): Size threshold in KiB
    """
    # Convert KiB to bytes
    size_threshold_bytes = size_threshold_kb * 1024
    
    # Search pattern for TensorFlow event files
    search_pattern = os.path.join(root_path, '**', 'events.out.tfevents*')
    
    # Find all matching files
    for event_file in glob.glob(search_pattern, recursive=True):
        try:
            # Get file size
            file_size = os.path.getsize(event_file)
            
            if file_size < size_threshold_bytes:
                # Get parent directory
                parent_dir = os.path.dirname(event_file)
                
                print(f"Found small event file: {event_file}")
                print(f"Size: {file_size/1024:.2f} KiB")
                print(f"Deleting folder: {parent_dir}")
                
                # Delete the parent directory and all its contents
                shutil.rmtree(parent_dir)
                
        except (OSError, PermissionError) as e:
            print(f"Error processing {event_file}: {e}")

# %%
log_dir = "./logs"
clean_small_tf_event_folders(log_dir)
# Out:
# Found small event file: ./logs/log_MFNet_swin_b_MLPDecoder/tb/Oct14_14-10-19/events.out.tfevents.1728868769.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/log_MFNet_swin_b_MLPDecoder/tb/Oct14_14-10-19
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoder_IFRM_CrossEntropyLoss/tb/Oct17_17-10-39/events.out.tfevents.1729129157.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoder_IFRM_CrossEntropyLoss/tb/Oct17_17-10-39
# Error processing ./logs/MFNet/log_mit_b2_MLPDecoder_IFRM_CrossEntropyLoss/tb/Oct17_17-10-39/events.out.tfevents.1729129192.Threadripper3990x: [Errno 2] No such file or directory: './logs/MFNet/log_mit_b2_MLPDecoder_IFRM_CrossEntropyLoss/tb/Oct17_17-10-39/events.out.tfevents.1729129192.Threadripper3990x'
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoder_IFRM_CrossEntropyLoss/tb/Dec18_18-11-16/events.out.tfevents.1734488207.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoder_IFRM_CrossEntropyLoss/tb/Dec18_18-11-16
# Found small event file: ./logs/MFNet/log_swin_s_MLPDecoder_IFRM_IFFM_CrossEntropyLoss/tb/Oct18_18-16-17/events.out.tfevents.1729235862.Threadripper3990x
# Size: 0.00 KiB
# Deleting folder: ./logs/MFNet/log_swin_s_MLPDecoder_IFRM_IFFM_CrossEntropyLoss/tb/Oct18_18-16-17
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-11-34/events.out.tfevents.1734316481.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-11-34
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-11-36/events.out.tfevents.1734316568.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-11-36
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-36/events.out.tfevents.1734406575.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-36
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-39/events.out.tfevents.1734406773.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-39
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-37/events.out.tfevents.1734406667.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-37
# Error processing ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-37/events.out.tfevents.1734406636.Threadripper3990x: [Errno 2] No such file or directory: './logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-37/events.out.tfevents.1734406636.Threadripper3990x'
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-52/events.out.tfevents.1734407569.Threadripper3990x
# Size: 1.30 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-52
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-25/events.out.tfevents.1734405939.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-25
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-45/events.out.tfevents.1734407105.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-45
# Error processing ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-45/events.out.tfevents.1734407147.Threadripper3990x: [Errno 2] No such file or directory: './logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-45/events.out.tfevents.1734407147.Threadripper3990x'
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-46/events.out.tfevents.1734407166.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-46
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-38/events.out.tfevents.1734406701.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-38
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-40/events.out.tfevents.1734406841.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoderpp_IFRM_CrossEntropyLoss_22k/tb/Dec17_17-12-40
# Found small event file: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-29/events.out.tfevents.1734312590.Threadripper3990x
# Size: 0.00 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-29
# Found small event file: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-21/events.out.tfevents.1734312062.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-21
# Found small event file: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-22/events.out.tfevents.1734312142.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-22
# Found small event file: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-42/events.out.tfevents.1734313328.Threadripper3990x
# Size: 0.23 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-42
# Found small event file: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-40/events.out.tfevents.1734313227.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-40
# Found small event file: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-33/events.out.tfevents.1734312820.Threadripper3990x
# Size: 0.00 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-33
# Error processing ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-33/events.out.tfevents.1734312799.Threadripper3990x: [Errno 2] No such file or directory: './logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-33/events.out.tfevents.1734312799.Threadripper3990x'
# Found small event file: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-31/events.out.tfevents.1734312699.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_pp_MLPDecoder_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-10-31
# Found small event file: ./logs/MFNet/log_mit_b0_MLPDecoderpp_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-11-45/events.out.tfevents.1734317129.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b0_MLPDecoderpp_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-11-45
# Found small event file: ./logs/MFNet/log_mit_b0_MLPDecoderpp_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-11-47/events.out.tfevents.1734317224.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b0_MLPDecoderpp_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-11-47
# Found small event file: ./logs/MFNet/log_mit_b0_MLPDecoderpp_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-11-46/events.out.tfevents.1734317178.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b0_MLPDecoderpp_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-11-46
# Found small event file: ./logs/MFNet/log_mit_b0_MLPDecoderpp_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-11-38/events.out.tfevents.1734316708.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b0_MLPDecoderpp_IFRM_CrossEntropyLoss_ssl_thermal/tb/Dec16_16-11-38
# Found small event file: ./logs/MFNet/log_resnet101_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-35/events.out.tfevents.1734485746.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet101_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-35
# Found small event file: ./logs/MFNet/log_resnet101_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-36/events.out.tfevents.1734485765.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet101_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-36
# Found small event file: ./logs/MFNet/log_resnet101_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-33/events.out.tfevents.1734485624.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet101_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-33
# Found small event file: ./logs/MFNet/log_resnet101_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-19/events.out.tfevents.1734484789.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet101_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-19
# Found small event file: ./logs/MFNet/log_resnet101_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-25/events.out.tfevents.1734485116.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet101_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-25
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-00/events.out.tfevents.1734487225.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-00
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-12/events.out.tfevents.1734487973.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-12
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-10/events.out.tfevents.1734487803.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-10
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-19/events.out.tfevents.1734488361.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-19
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-14/events.out.tfevents.1734488080.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-14
# Error processing ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-14/events.out.tfevents.1734488063.Threadripper3990x: [Errno 2] No such file or directory: './logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-14/events.out.tfevents.1734488063.Threadripper3990x'
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-07/events.out.tfevents.1734487667.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-07
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-15/events.out.tfevents.1734488145.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-15
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-54/events.out.tfevents.1734486854.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-54
# Error processing ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-54/events.out.tfevents.1734486891.Threadripper3990x: [Errno 2] No such file or directory: './logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-54/events.out.tfevents.1734486891.Threadripper3990x'
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-06/events.out.tfevents.1734487565.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-06
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-48/events.out.tfevents.1734486524.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-48
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-26/events.out.tfevents.1734488790.Threadripper3990x
# Size: 0.00 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-26
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-03/events.out.tfevents.1734487419.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-03
# Error processing ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-03/events.out.tfevents.1734487430.Threadripper3990x: [Errno 2] No such file or directory: './logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-03/events.out.tfevents.1734487430.Threadripper3990x'
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-23/events.out.tfevents.1734488587.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-23
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-39/events.out.tfevents.1734485959.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-39
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-16/events.out.tfevents.1734488164.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-16
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-22/events.out.tfevents.1734488521.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-22
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-59/events.out.tfevents.1734487165.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-59
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-38/events.out.tfevents.1734485917.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-38
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-11/events.out.tfevents.1734487869.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-11-11
# Found small event file: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-57/events.out.tfevents.1734487039.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_resnet50_MLPDecoderpp_IFRM_CrossEntropyLoss/tb/Dec18_18-10-57
# Found small event file: ./logs/MFNet/log_mit_b2_MLPDecoder_IFRM_IFFM_CrossEntropyLoss/tb/Oct18_18-15-54/events.out.tfevents.1729234475.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/MFNet/log_mit_b2_MLPDecoder_IFRM_IFFM_CrossEntropyLoss/tb/Oct18_18-15-54
# Found small event file: ./logs/log_MFNet_mit_b2_mask2former/tb/Oct15_15-09-58/events.out.tfevents.1728953887.Threadripper3990x
# Size: 0.00 KiB
# Deleting folder: ./logs/log_MFNet_mit_b2_mask2former/tb/Oct15_15-09-58
# Found small event file: ./logs/log_MFNet_mit_b2_MLPDecoder_sigmoidfocal/tb/Oct15_15-17-04/events.out.tfevents.1728979490.Threadripper3990x
# Size: 0.09 KiB
# Deleting folder: ./logs/log_MFNet_mit_b2_MLPDecoder_sigmoidfocal/tb/Oct15_15-17-04
# Found small event file: ./logs/log_MFNet_mit_b2_MLPDecoder_sigmoidfocal/tb/Oct15_15-17-03/events.out.tfevents.1728979401.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/log_MFNet_mit_b2_MLPDecoder_sigmoidfocal/tb/Oct15_15-17-03
# Found small event file: ./logs/log_MFNet_mit_b2_MLPDecoder_sigmoidfocal/tb/Oct15_15-17-02/events.out.tfevents.1728979335.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/log_MFNet_mit_b2_MLPDecoder_sigmoidfocal/tb/Oct15_15-17-02
# Found small event file: ./logs/log_MFNet_mit_b2/tb/Oct04_04-09-58/events.out.tfevents.1728003539.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/log_MFNet_mit_b2/tb/Oct04_04-09-58
# Found small event file: ./logs/log_MFNet_mit_b2/tb/Oct04_04-10-01/events.out.tfevents.1728003660.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/log_MFNet_mit_b2/tb/Oct04_04-10-01
# Found small event file: ./logs/log_MFNet_mit_b2/tb/Oct04_04-10-13/events.out.tfevents.1728004433.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/log_MFNet_mit_b2/tb/Oct04_04-10-13
# Found small event file: ./logs/log_MFNet_mit_b2/tb/Oct04_04-10-16/events.out.tfevents.1728004587.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/log_MFNet_mit_b2/tb/Oct04_04-10-16
# Found small event file: ./logs/log_MFNet_mit_b4/tb/Oct08_08-09-50/events.out.tfevents.1728348640.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/log_MFNet_mit_b4/tb/Oct08_08-09-50
# Found small event file: ./logs/log_MFNet_mit_b4/tb/Oct08_08-09-53/events.out.tfevents.1728348816.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/log_MFNet_mit_b4/tb/Oct08_08-09-53
# Found small event file: ./logs/log_MFNet_mit_b4/tb/Oct08_08-10-26/events.out.tfevents.1728350766.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/log_MFNet_mit_b4/tb/Oct08_08-10-26
# Found small event file: ./logs/log_MFNet_mit_b4/tb/Oct08_08-09-51/events.out.tfevents.1728348689.Threadripper3990x
# Size: 0.04 KiB
# Deleting folder: ./logs/log_MFNet_mit_b4/tb/Oct08_08-09-51
